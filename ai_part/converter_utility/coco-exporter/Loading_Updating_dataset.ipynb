# %%
#COCO Image Viewer
#This notebook will allow you to view details about a COCO dataset and preview segmentations on annotated images. Learn more about it at: http://cocodataset.org/
import IPython
import os
import json
import random
import numpy as np
import requests
from io import BytesIO
from math import trunc
from PIL import Image as PILImage
from PIL import ImageDraw as PILImageDraw

# Load the dataset json
class CocoDataset():
    def __init__(self, annotation_path, image_dir):
        self.annotation_path = annotation_path
        self.image_dir = image_dir
        self.colors = ['blue', 'purple', 'red', 'green', 'orange', 'salmon', 'pink', 'gold',
                       'orchid', 'slateblue', 'limegreen', 'seagreen', 'darkgreen', 'olive',
                       'teal', 'aquamarine', 'steelblue', 'powderblue', 'dodgerblue', 'navy',
                       'magenta', 'sienna', 'maroon']

        json_file = open(self.annotation_path)
        self.coco = json.load(json_file)
        json_file.close()

        self.process_info()
        self.process_licenses()
        self.process_categories()
        self.process_images()
        self.process_segmentations()

    def display_info(self):
        print('Dataset Info:')
        print('=============')
        if self.info is None:
            return
        for key, item in self.info.items():
            print('  {}: {}'.format(key, item))

        requirements = [['description', str],
                        ['url', str],
                        ['version', str],
                        ['year', int],
                        ['contributor', str],
                        ['date_created', str]]
        for req, req_type in requirements:
            if req not in self.info:
                print('ERROR: {} is missing'.format(req))
            elif type(self.info[req]) != req_type:
                print('ERROR: {} should be type {}'.format(req, str(req_type)))
        print('')

    def display_licenses(self):
        print('Licenses:')
        print('=========')

        if self.licenses is None:
            return
        requirements = [['id', int],
                        ['url', str],
                        ['name', str]]
        for license in self.licenses:
            for key, item in license.items():
                print('  {}: {}'.format(key, item))
            for req, req_type in requirements:
                if req not in license:
                    print('ERROR: {} is missing'.format(req))
                elif type(license[req]) != req_type:
                    print('ERROR: {} should be type {}'.format(
                        req, str(req_type)))
            print('')
        print('')

    def display_categories(self):
        print('Categories:')
        print('=========')
        for sc_key, sc_val in self.super_categories.items():
            print('  super_category: {}'.format(sc_key))
            for cat_id in sc_val:
                print('    id {}: {}'.format(
                    cat_id, self.categories[cat_id]['name']))
            print('')

    def display_image(self, image_id, show_polys=True, show_bbox=True, show_crowds=True, use_url=False):
        print('Image:')
        print('======')
        if image_id == 'random':
            image_id = random.choice(list(self.images.keys()))

        # Print the image info
        image = self.images[image_id]
        for key, val in image.items():
            print('  {}: {}'.format(key, val))

        # Open the image
        if use_url:
            image_path = image['coco_url']
            response = requests.get(image_path)
            image = PILImage.open(BytesIO(response.content))

        else:
            image_path = os.path.join(self.image_dir, image['file_name'])
            image = PILImage.open(image_path)

        # Calculate the size and adjusted display size
        max_width = 600
        image_width, image_height = image.size
        adjusted_width = min(image_width, max_width)
        adjusted_ratio = adjusted_width / image_width
        adjusted_height = adjusted_ratio * image_height

        # Create list of polygons to be drawn
        polygons = {}
        bbox_polygons = {}
        rle_regions = {}
        poly_colors = {}
        bbox_categories = {}
        print('  segmentations ({}):'.format(
            len(self.segmentations[image_id])))
        for i, segm in enumerate(self.segmentations[image_id]):
            polygons_list = []
            if segm['iscrowd'] != 0:
                # Gotta decode the RLE
                px = 0
                x, y = 0, 0
                rle_list = []
                for j, counts in enumerate(segm['segmentation']['counts']):
                    if j % 2 == 0:
                        # Empty pixels
                        px += counts
                    else:
                        # Need to draw on these pixels, since we are drawing in vector form,
                        # we need to draw horizontal lines on the image
                        x_start = trunc(
                            trunc(px / image_height) * adjusted_ratio)
                        y_start = trunc(px % image_height * adjusted_ratio)
                        px += counts
                        x_end = trunc(trunc(px / image_height)
                                      * adjusted_ratio)
                        y_end = trunc(px % image_height * adjusted_ratio)
                        if x_end == x_start:
                            # This is only on one line
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (y_end - y_start)})
                        if x_end > x_start:
                            # This spans more than one line
                            # Insert top line first
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (image_height - y_start)})

                            # Insert middle lines if needed
                            lines_spanned = x_end - x_start + 1  # total number of lines spanned
                            full_lines_to_insert = lines_spanned - 2
                            if full_lines_to_insert > 0:
                                full_lines_to_insert = trunc(
                                    full_lines_to_insert * adjusted_ratio)
                                rle_list.append(
                                    {'x': (x_start + 1), 'y': 0, 'width': full_lines_to_insert, 'height': image_height})

                            # Insert bottom line
                            rle_list.append(
                                {'x': x_end, 'y': 0, 'width': 1, 'height': y_end})
                if len(rle_list) > 0:
                    rle_regions[segm['id']] = rle_list
            else:
                # Add the polygon segmentation
                for segmentation_points in segm['segmentation']:
                    segmentation_points = np.multiply(
                        segmentation_points, adjusted_ratio).astype(int)
                    polygons_list.append(
                        str(segmentation_points).lstrip('[').rstrip(']'))
            polygons[segm['id']] = polygons_list
            if i < len(self.colors):
                poly_colors[segm['id']] = self.colors[i]
            else:
                poly_colors[segm['id']] = 'white'

            bbox = segm['bbox']
            bbox_points = [bbox[0], bbox[1], bbox[0] + bbox[2], bbox[1],
                           bbox[0] + bbox[2], bbox[1] +
                           bbox[3], bbox[0], bbox[1] + bbox[3],
                           bbox[0], bbox[1]]
            bbox_points = np.multiply(bbox_points, adjusted_ratio).astype(int)
            bbox_polygons[segm['id']] = str(
                bbox_points).lstrip('[').rstrip(']')
            bbox_categories[segm['id']] = self.categories[segm['category_id']]
            # Print details
            print('    {}:{}:{}'.format(
                segm['id'], poly_colors[segm['id']], self.categories[segm['category_id']]))

        # Draw segmentation polygons on image
        html = '<div class="container" style="position:relative;">'
        html += '<img src="{}" style="position:relative;top:0px;left:0px;width:{}px;">'.format(
            image_path, adjusted_width)
        html += '<div class="svgclass"><svg width="{}" height="{}">'.format(
            adjusted_width, adjusted_height)

        if show_polys:
            for seg_id, points_list in polygons.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for points in points_list:
                    html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5" />'.format(
                        points, fill_color, stroke_color)

        if show_crowds:
            for seg_id, rect_list in rle_regions.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for rect_def in rect_list:
                    x, y = rect_def['x'], rect_def['y']
                    w, h = rect_def['width'], rect_def['height']
                    html += '<rect x="{}" y="{}" width="{}" height="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5; stroke-opacity:0.5" />'.format(
                        x, y, w, h, fill_color, stroke_color)

        if show_bbox:
            for seg_id, points in bbox_polygons.items():
                x, y = [int(i) for i in points.split()[:2]]
                html += '<text x="{}" y="{}" fill="yellow">{}</text>'.format(
                    x, y, bbox_categories[seg_id]["name"])
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0" />'.format(
                    points, fill_color, stroke_color)

        html += '</svg></div>'
        html += '</div>'
        html += '<style>'
        html += '.svgclass { position:absolute; top:0px; left:0px;}'
        html += '</style>'
        return html

    def process_info(self):
        self.info = self.coco.get('info')

    def process_licenses(self):
        self.licenses = self.coco.get('licenses')

    def process_categories(self):
        self.categories = {}
        self.super_categories = {}
        for category in self.coco['categories']:
            cat_id = category['id']
            super_category = category['supercategory']

            # Add category to the categories dict
            if cat_id not in self.categories:
                self.categories[cat_id] = category
            else:
                print("ERROR: Skipping duplicate category id: {}".format(category))

            # Add category to super_categories dict
            if super_category not in self.super_categories:
                # Create a new set with the category id
                self.super_categories[super_category] = {cat_id}
            else:
                self.super_categories[super_category] |= {
                    cat_id}  # Add category id to the set

    def process_images(self):
        self.images = {}
        for image in self.coco['images']:
            image_id = image['id']
            
            if image_id in self.images:
                print("ERROR: Skipping duplicate image id: {}".format(image))
            else:
                self.images[image_id] = image
          
        #print("in process images", self.images)
        
        
        

    def process_segmentations(self):
        self.segmentations = {}
        for segmentation in self.coco['annotations']:
            image_id = segmentation['image_id']
            if image_id not in self.segmentations:
                self.segmentations[image_id] = []
            self.segmentations[image_id].append(segmentation)

# %%
annotation_path = 'output_coco/coco_all_vf.json'
image_dir = ''

coco_dataset_all = CocoDataset(annotation_path, image_dir)
coco_dataset_all.display_info()
coco_dataset_all.display_licenses()
coco_dataset_all.display_categories()
# Out:
# Dataset Info:
# =============
#   year: 2020
#   version: None
#   description: CleanOut
#   contributor: sara.elateif@gmail.com
#   url: labelbox.com
#   date_created: 2020-09-20T08:39:41.252233+00:00
# ERROR: version should be type <class 'str'>
#
# Licenses:
# =========
#
# Categories:
# =========
#   super_category: mask
#     id 1: mask
#
#   super_category: tissue
#     id 2: tissue
#
#   super_category: glove
#     id 3: glove
#
#   super_category: sanitizer_gel
#     id 4: sanitizer_gel

# %%
from collections import OrderedDict 
 
catgs = coco_dataset_all.coco['categories']
catgs
srtd  = sorted(catgs, key = lambda i: i['id']) 

catg_ids =  [ sub['id'] for sub in srtd ] 


ctg_list = [ sub['name'] for sub in srtd ] 
ctg_dir = [ sub.replace(' ', '') for sub in ctg_list]  
ctg_dir = [ sub.replace('/', '_') for sub in ctg_dir]
ctg_dir = [ sub.replace(",", '_') for sub in ctg_dir] 


ctg_dir = [ sub.replace('\'', '') for sub in ctg_dir]  
ctg_dirs = dict(zip(catg_ids, ctg_dir))
print('category dirs:', ctg_dirs)
ctg_pfx = []
print(len(ctg_dir))
print(ctg_dir)
for i in range(len(ctg_dir)):
    #ctg_pfx.append(  str(catg_ids[i]) + '_'+ctg_dir[i])
    ctg_pfx.append(  ctg_dir[i])

ctg_pfx
catg_pfx = dict(zip(catg_ids, ctg_pfx))
catg_pfx
# Out:
# category dirs: {1: 'mask', 2: 'tissue', 3: 'glove', 4: 'sanitizer_gel'}
# 4
# ['mask', 'tissue', 'glove', 'sanitizer_gel']
# {1: 'mask', 2: 'tissue', 3: 'glove', 4: 'sanitizer_gel'}

# %%
from pathlib import Path
from tqdm import tqdm
import numpy as np
import json
import urllib
import PIL.Image as Image
import cv2
import torch
import torchvision
from IPython.display import display
from sklearn.model_selection import train_test_split

import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
# %matplotlib inline


def create_cons_dataset( dataset):
    
    for key in ctg_dirs:
        catg = ctg_dirs[key]
        tr = Path(f"tr")
        tr.mkdir(parents=True, exist_ok=True)
        catgy_path = Path(f"{tr}/{catg}")
        catgy_path.mkdir(parents=True, exist_ok=True)
        images_path = Path(f"{tr}/{catg}/images")
        images_path.mkdir(parents=True, exist_ok=True)


    catgs = dataset.coco['categories']
    
    imageslist = dataset.coco['images']
    print(': creating Dataset of images and labels for COCO...')
    i = 0
    noant_imgs= 0
    category=''
    for img in imageslist:
        imgid = img['id']
    
        if (imgid not in dataset.segmentations):
            noant_imgs = noant_imgs+1
            print( ': no annotations for image id', imgid)
            continue        
    
        a_list = dataset.segmentations[imgid]
        ctg_id = a_list[0]['category_id']
        if(category != catg_pfx[ctg_id ]):
            category = catg_pfx[ctg_id ]
            print('Converting ', category, '....')
        
        catg_name = catgs['id' == ctg_id]['name']
        cpfx = catg_pfx[ctg_id]
        
        images_path ='tr/'+cpfx+'/images'
        
        img_det = dataset.coco['images']['id'==imgid]
    
        imageid = img['coco_url']
    
        #image_name = f"{cpfx}_{i}.jpeg"
        image_name = f"{imgid}.jpeg"
        #print(image_name)
        img = urllib.request.urlopen(imageid)
        img = Image.open(img)
        img = img.convert('RGB')
        img.save(str(images_path+ '/'+ image_name), "JPEG")
        w = img_det['width']
        h = img_det['height']

        i= i+1
    print(catg, ': Finished Dataset of images and labels for COCO : count ',i+1 )
    print(catg, ': JSON does not have annotations for images: count ', noant_imgs )

# %%
create_cons_dataset(coco_dataset_all)
# Out:
# : creating Dataset of images and labels for COCO...
# Converting  mask ....
# Converting  tissue ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckestehjm00043j5rrt4lfczv
# Converting  glove ....
# : no annotations for image id ckestivu600073j5rn56io4i0
# : no annotations for image id ckestj6h100083j5rphidoe40
# : no annotations for image id ckestjkfp00093j5ru3cjgfs4
# : no annotations for image id ckestjoq9000a3j5rplqw01ls
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckestohsi000f3j5rsg0dia7f
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckestwvaq000m3j5r6zhj20i0
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckesu5fa5000u3j5ruk6m5rvd
# : no annotations for image id ckesu65bq000w3j5rmk9ydre5
# : no annotations for image id ckesu6938000x3j5rck1bxx9v
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckev6ivw400033b5s7ddc0b5x
# Converting  mask ....
# : no annotations for image id ckev6khtk00063b5s72d6h25b
# : no annotations for image id ckev6pv77000a3b5s8vdywo0y
# : no annotations for image id ckev6tev5000g3b5sae8aq87t
# : no annotations for image id ckev6tpmw000h3b5s8p156stp
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckevi7neh00053j5r4yep92pb
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckevicab1000c3j5rwtzwh0wl
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckevifagj000i3j5r0blu3l5j
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  tissue ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckeviql2d000y3j5r4hbksrwj
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckeviwevk00133j5ro7fed00g
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckewpzka100073j5rcmstdy1o
# Converting  mask ....
# : no annotations for image id ckewqa5ro000h3j5rih56l51z
# Converting  glove ....
# Converting  tissue ....
# Converting  mask ....
# Converting  tissue ....
# Converting  glove ....
# : no annotations for image id ckewqgowd000p3j5rgf4ty3i1
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckey6cxsf00053j5rvb3cxvqg
# : no annotations for image id ckey6fmb2000b3j5rtj2t740h
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckey6kklj000i3j5rxqgp0ysc
# Converting  mask ....
# : no annotations for image id ckey6w164000o3j5rvjgggdzy
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckeymcrjl00043b5szec7alld
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckezeiohz000c3b5sac50nhpk
# Converting  mask ....
# Converting  tissue ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckezhtown00013j5raw3pdmxj
# Converting  sanitizer_gel ....
# : no annotations for image id ckezhum9c00033j5rjif5spvt
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckezvf06300073j5r573za2lx
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckezvgp2g000a3j5r3d0es9o7
# : no annotations for image id ckezvgrbq000b3j5rkah2ey6u
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckezw43x800063j5rah9lqdxt
# Converting  glove ....
# Converting  tissue ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf3tn3ey000k3j5rsk8t8lmy
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  tissue ....
# Converting  mask ....
# : no annotations for image id ckf3ufed0000y3j5re6zk4t84
# : no annotations for image id ckf3ufjcr000z3j5r41vynt9v
# : no annotations for image id ckf3ufm2g00103j5rhdqqdcer
# : no annotations for image id ckf3uh0ao00133j5rvcpzin6o
# : no annotations for image id ckf3uh5na00143j5r5txuuwl6
# : no annotations for image id ckf3ul9e200183j5rwnd9c23w
# Converting  glove ....
# : no annotations for image id ckf3uoxr5001a3j5rq2fxrrzu
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  tissue ....
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckf3vlk8j001t3j5rke1uufms
# Converting  mask ....
# Converting  tissue ....
# : no annotations for image id ckf3vvpuw00243j5rpp3mho1l
# : no annotations for image id ckf3vvsf600253j5rbrpa7ecj
# Converting  mask ....
# : no annotations for image id ckf3vxr3s00283j5rn7o9zot9
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf3vzuok002b3j5roh6poqud
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf3wdhh2002g3j5rfx29d3zr
# : no annotations for image id ckf3we3rv002h3j5rtioky95u
# : no annotations for image id ckf3wfi0c002j3j5r2w8dnr5c
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf4009tg00033j5rtggx5zci
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckf4057dg000a3j5r1s8m0l7d
# : no annotations for image id ckf405ak3000b3j5r2grdsde2
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckf40a8mt000h3j5rxgi24pmf
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckf40dage000l3j5rvhfvy6r9
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf46cotp000f3k5rreh3u9jd
# Converting  glove ....
# : no annotations for image id ckf46da74000h3k5rbkpsbvwf
# Converting  mask ....
# : no annotations for image id ckf46gkrz000l3k5rvk95imfz
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf46uimx00073k5rn3uwvrnn
# Converting  glove ....
# : no annotations for image id ckf46woj3000b3k5rq8x7x286
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf48ja7c00063k5rlo28c7ji
# Converting  tissue ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  tissue ....
# Converting  glove ....
# Converting  mask ....
# Converting  tissue ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  tissue ....
# Converting  mask ....
# : no annotations for image id ckf5n1lpm00053k5rl9xow14f
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf5ndx7a000h3k5rivi2gcir
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf5o00cd000p3k5rru1e2lfl
# Converting  glove ....
# Converting  mask ....
# Converting  tissue ....
# Converting  mask ....
# : no annotations for image id ckf5o9x39000x3k5rvsvu7h3n
# : no annotations for image id ckf5obpwo000z3k5r5u3c1n71
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf6j6ip000053b5zomuq0gnu
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckf6jk73i00053b5zd7l7c7lk
# Converting  mask ....
# : no annotations for image id ckf6k5x08000a3b5zwpji8vhz
# Converting  glove ....
# : no annotations for image id ckf6kahmk000f3b5zoy3dy3oe
# Converting  mask ....
# Converting  glove ....
# Converting  tissue ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf6klyku000c3b5zw8s9oflq
# : no annotations for image id ckf6km1vq000d3b5z328d68du
# : no annotations for image id ckf6knrii000h3b5zpuldef5k
# : no annotations for image id ckf6kpcpm000k3b5zifdaz8ao
# Converting  glove ....
# : no annotations for image id ckf6krjl9000n3b5z85fn0h46
# Converting  mask ....
# Converting  tissue ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  tissue ....
# : no annotations for image id ckf6kxz6b00083b5z9jvy7wx0
# : no annotations for image id ckf6ky0qk00093b5zad25f8o3
# Converting  mask ....
# : no annotations for image id ckf6l0mpt000e3b5zmpyd6ipm
# Converting  tissue ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf6l7mo600073b5zjkr7joh4
# : no annotations for image id ckf6l7sap00083b5zrda5o7z8
# Converting  glove ....
# : no annotations for image id ckf6l9b64000b3b5z3lhkp0qs
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  tissue ....
# Converting  mask ....
# : no annotations for image id ckf81tu9c000a3b5z2haq8dfa
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf81xku8000g3b5zvg870vas
# : no annotations for image id ckf81xsp5000h3b5z7ou7p84z
# Converting  glove ....
# : no annotations for image id ckf820wty000k3b5zts9l1sum
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckf8243hb000o3b5zo2qjh8f4
# : no annotations for image id ckf826ioe00013b5zt6fa6ey4
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  sanitizer_gel ....
# : no annotations for image id ckf82f4eb00073b5zm92bo6h6
# Converting  mask ....
# : no annotations for image id ckf82flkv00093b5zaxp21ez9
# : no annotations for image id ckf82gc28000c3b5z5s5hskv9
# Converting  glove ....
# : no annotations for image id ckf82mew000013b5zl15ksfcb
# Converting  mask ....
# : no annotations for image id ckf85ef4k00003k60vbp17w3f
# Converting  glove ....
# : no annotations for image id ckf85hc8000043k60dgs5tl7z
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf86wwc600043k60u5dcd02q
# Converting  tissue ....
# Converting  glove ....
# : no annotations for image id ckf874fic000c3k60hn35hiib
# Converting  mask ....
# : no annotations for image id ckf87cj1z000e3k60et8bkw72
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckf8dwp3s00093k6097iui2sx
# : no annotations for image id ckf8dwrg7000a3k60sw8nd6nb
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf8e2093000g3k60u0bkgc0j
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf8efkoq000p3k60zuiqt10q
# Converting  glove ....
# Converting  mask ....
# Converting  tissue ....
# : no annotations for image id ckf8gtkmv000t3k60i0qvolap
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf8gw635000x3k60t9p4tmyk
# : no annotations for image id ckf8gwe9z000y3k60ph6rnoah
# : no annotations for image id ckf8hdy3e00113k60d0o3rnet
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf8hivs700153k60h5du24ge
# : no annotations for image id ckf8hti9e00043k6084btznkj
# : no annotations for image id ckf8hu4ff00063k60edrf8g5j
# : no annotations for image id ckf8hu6ah00073k609l40rjh4
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckf8i0jfp000e3k60w76c9yrt
# Converting  tissue ....
# Converting  glove ....
# : no annotations for image id ckf8i1vdh000h3k603j8u574m
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckf8pw5ct00023k603fco0xoh
# : no annotations for image id ckf8pw9q100033k60wls01qvw
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf8pzi6300083k60qnt1cxy1
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  tissue ....
# Converting  glove ....
# : no annotations for image id ckf9dudhz00083b5zt70tkog0
# : no annotations for image id ckf9dvvnv000a3b5zkisepwf8
# : no annotations for image id ckf9dvxy2000b3b5z77v24u0i
# Converting  mask ....
# : no annotations for image id ckf9dyx8p00013b5z028w8r64
# : no annotations for image id ckf9dzizo00033b5zhnznx3ll
# : no annotations for image id ckf9dzmfl00043b5zz83xrtmo
# : no annotations for image id ckf9dzr2500053b5zdc38ppsp
# : no annotations for image id ckf9e0r5200063b5zheosmd20
# : no annotations for image id ckf9e0vdm00073b5zlj4hzgef
# : no annotations for image id ckf9e24do00093b5zfmjvztux
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckf9e9koa000l3b5zgazla0uy
# Converting  mask ....
# Converting  tissue ....
# Converting  mask ....
# : no annotations for image id ckf9ec00x000p3b5zqsoj5yi4
# : no annotations for image id ckf9ejue000003b5zy2msu2jf
# : no annotations for image id ckf9ejz5u00013b5zd8xvg2x9
# : no annotations for image id ckf9etmm400043b5zsyx16o9y
# : no annotations for image id ckf9etpso00053b5z26pc7i5a
# : no annotations for image id ckf9evukz00083b5zw3u33pk9
# : no annotations for image id ckf9evxsn00093b5z3f31kkwb
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf9fdc71000i3b5zvw8l8too
# Converting  glove ....
# : no annotations for image id ckf9fj5ll00023b5z76bhfe72
# : no annotations for image id ckf9fj96x00033b5zrcqp5ebq
# : no annotations for image id ckf9fjbr700043b5zz1b1ifrs
# : no annotations for image id ckf9fjewg00053b5zqcph0czy
# Converting  tissue ....
# Converting  mask ....
# : no annotations for image id ckf9flasb00083b5zx7jnivnl
# : no annotations for image id ckf9fldxq00093b5zdtwe62jd
# : no annotations for image id ckf9flgct000a3b5z0rlxyejb
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf9fn94q000d3b5z2olkp7a6
# : no annotations for image id ckf9fojuq000g3b5znqeuc0bt
# : no annotations for image id ckf9fpqqq000j3b5znuh0zmon
# : no annotations for image id ckf9ft21h00033b5zokvxjjnd
# : no annotations for image id ckf9ft4sl00043b5zrg2ta1q5
# : no annotations for image id ckf9fy1o300083b5z6k4rnnxx
# : no annotations for image id ckf9fy7uq00093b5zcvz3civj
# : no annotations for image id ckf9fyz3z000b3b5zgq6ay3fg
# : no annotations for image id ckf9g2vlu00003b5zvg8uxqcx
# : no annotations for image id ckf9gcj5o00013b5zhulfylsh
# : no annotations for image id ckf9gdewk00033b5zbj70rh2j
# Converting  glove ....
# Converting  tissue ....
# : no annotations for image id ckf9gf4nj00063b5zt6cufug6
# Converting  mask ....
# : no annotations for image id ckf9gnx3l00053b5z7v8bpeyv
# : no annotations for image id ckf9gq34q00003b5zu0xdt1sh
# : no annotations for image id ckf9gu6vc00033b5zdjahyoeq
# : no annotations for image id ckf9gvkyq00053b5zcw87d3vd
# : no annotations for image id ckf9gx5lj00003b5zdfaf6yr4
# Converting  glove ....
# : no annotations for image id ckf9gz6gx00003b5zu6o8zvvl
# : no annotations for image id ckf9gziix00013b5z2rfbfcfs
# : no annotations for image id ckf9h004y00023b5z0ukeybot
# : no annotations for image id ckf9h05rf00033b5zwpkmmo9e
# : no annotations for image id ckf9h0dsc00043b5zq5ie1wok
# : no annotations for image id ckf9h0kpp00053b5zzyi3ldle
# : no annotations for image id ckf9h0tkk00063b5z6agtrprc
# : no annotations for image id ckf9h0yhz00073b5zvvhv9akc
# : no annotations for image id ckf9h4d3700083b5zy38mi81q
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# Converting  glove ....
# Converting  tissue ....
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckf9i5edc00073b5z8fimvic7
# Converting  mask ....
# : no annotations for image id ckf9i7x54000a3b5zyo61s8nw
# : no annotations for image id ckf9ifxhm00013b5zih3xyfi2
# : no annotations for image id ckf9ih90a00043b5zk7xvnkft
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf9imb4v00023b5z0zp9ss17
# Converting  sanitizer_gel ....
# : no annotations for image id ckf9inc5b00043b5zwe04n84a
# Converting  mask ....
# Converting  glove ....
# Converting  mask ....
# : no annotations for image id ckf9ivb6y00013b5z58n1i6g0
# : no annotations for image id ckf9ivik000023b5zmmzksvu6
# : no annotations for image id ckf9ivnmi00033b5zh8huntff
# Converting  tissue ....
# Converting  mask ....
# Converting  glove ....
# : no annotations for image id ckf9iyteg00073b5zjebnmbzs
# : no annotations for image id ckf9iyx1c00083b5zfbzrmogj
# Converting  mask ....
# : no annotations for image id ckf9j009z000a3b5zb3vxv6yi
# : no annotations for image id ckf9j2i6100003b5zdi8d5ujm
# : no annotations for image id ckf9j2ojc00013b5zgd1fzazy
# : no annotations for image id ckf9j2ypu00023b5zumrfxc1u
# : no annotations for image id ckf9j4l8u00053b5zg6fk23a5
# : no annotations for image id ckf9j4w5300063b5z7jxpljk4
# : no annotations for image id ckf9j52zo00073b5zm1a3bx4l
# : no annotations for image id ckf9j9com00013b5zhhjksgpz
# : no annotations for image id ckf9j9iej00023b5zc4pkixwk
# : no annotations for image id ckf9j9nc300033b5zu98gncdc
# : no annotations for image id ckf9janhh00053b5zugiwk1p6
# : no annotations for image id ckf9jareb00063b5ze0sugx0p
# : no annotations for image id ckf9jbuwn00093b5zbq7z6vxb
# : no annotations for image id ckf9jcnel000b3b5z2gjts61o
# : no annotations for image id ckf9je2q600003b5zblh248pz
# : no annotations for image id ckf9jg1ky00033b5zyn3be0lw
# : no annotations for image id ckf9jgec600043b5zzirseye5
# : no annotations for image id ckf9jjpn800023b5zem35zo2u
# : no annotations for image id ckf9jjump00033b5zp0yynd34
# sanitizer_gel : Finished Dataset of images and labels for COCO : count  775
# sanitizer_gel : JSON does not have annotations for images: count  196

# %%
#!cp -r images/* ../../dataset/
#!ls ../../dataset/ | wc -l #4417

# %%
mkdir data

# %%
ls
# Out:
# Dockerfile                             data/
# Loading_Updating_dataset.ipynb         exceptions.py
# Makefile                               input_json/
# Pipfile                                main.py
# Pipfile.lock                           output_coco/
# README.md                              requirements.txt
# Update_Categories_ids.ipynb            test_labeling_coco_image_viewer.ipynb
# __pycache__/                           tr/
# coco_exporter.py

# %%
from pathlib import Path
import os 

dst = Path(f"./data")
imgs_npfx = Path(f"./tr/images")

directories = []
for dir in os.listdir('./tr'):
  directories.append(dir)

# %%
dst = "./data/"

for path in directories: 
    ipath = './tr/' + path + '/images/*'
    os.system(f"cp -r {ipath} {dst}")
